# %%
import pandas as pd
import os

# %%
data = pd.read_csv('DATA300 - ChatGPT Dataset - Sheet1.csv')
data.head()
# Out:
#                 Name  Gender  Age          Nationality  Years Active  \
# 0    Gabrielle Lopez  Female   28   Brazilian-American             6
# 1   Xavier Rodriguez    Male   34            Brazilian            12
# 2      Olivia Nguyen  Female   31  Vietnamese-American             9
# 3       Liam Johnson    Male   32              British            10
# 4  Isabella Martinez  Female   26              Spanish             4
#
#                       Genre/Niche  Beauty  \
# 0      Fashion, Beauty, Lifestyle       8
# 1     Fitness, Health, Motivation       9
# 2      Fashion, Lifestyle, Travel       9
# 3  Travel, Adventure, Photography       8
# 4        Food, Cooking, Lifestyle       7
#
#                                               Skills  \
# 0  Fashion styling, Makeup artistry, Content crea...
# 1     Personal training, Nutrition, Content creation
# 2  Fashion design, Travel blogging, Content creation
# 3         Photography, Travel blogging, Storytelling
# ...

# %%
def change_income(x):
    x['Income'] = x['Income'][1:]

        x['Income'].replace(",",'')
    return int(x['Income'])

data['Income'] = data.apply(change_income, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       3     x['Income'].replace(",",'')
#       4     return int(x['Income'])
# ----> 6 data['Income'] = data.apply(change_income, axis = 1)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# ...

# %%
data["Income"]
# Out:
# 0     500,000
# 1     600,000
# 2     700,000
# 3     400,000
# 4     250,000
# 5     600,000
# 6     450,000
# 7     800,000
# 8     550,000
# 9     300,000
# 10    400,000
# 11    550,000
# 12    500,000
# 13    700,000
# 14    650,000
# 15    400,000
# 16    550,000
# 17    800,000
# Name: Income, dtype: object
