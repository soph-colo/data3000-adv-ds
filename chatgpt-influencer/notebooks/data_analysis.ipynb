# %% [markdown]
# # Data Analysis

# %% [markdown]
# #### 0. Nationality

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
from matplotlib import pyplot as plt

# %%
os.chdir(path="/Users/sophiacolonello/Desktop/school/junior year/second semester/data3000-adv-ds/chatgpt-influencer/data/processed")
coeff = pd.read_csv("coefficents.csv")
data = pd.read_csv("chatgpt_data.csv")
condensed = pd.read_csv("chatgpt_data_final.csv")

# %%
coeff = coeff.sort_values(by = ['1'])
coeff
# Out:
#     Unnamed: 0                       0             1
# 24          24     High School Diploma -1.785543e+04
# 25          25                Master's -4.978947e+03
# 20          20                  Beauty -2.189371e+03
# 19          19                  Health -1.480455e+03
# 8            8                  Female -1.478517e+03
# 22          22              Bachelor's -1.153663e+03
# 3            3              Award_Wins -8.480603e+02
# 27          27               Introvert -6.234712e+02
# 15          15                 Oceanic  1.818989e-11
# 28          28               Extrovert  6.234712e+02
# 9            9                    Male  1.478517e+03
# 2            2            Beauty_Level  1.972798e+03
# 0            0                     Age  2.140669e+03
# 21          21                    Tech  2.664348e+03
# 18          18                  Travel  3.246492e+03
# 23          23         Culinary School  5.220471e+03
# 17          17                    Food  5.220471e+03
# ...

# %% [markdown]
# #### 0. Nationality

# %%
nationality_income = data.groupby(['Nationality'])['Income_Per_Year'].mean().to_frame().reset_index()
nationality_income = nationality_income.sort_values(by =['Income_Per_Year'])
X = nationality_income['Nationality']
y = nationality_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 27 artists>

# %% [markdown]
# ### 1. Beauty

# %%
beauty_income = data.groupby(['Beauty_Level'])['Income_Per_Year'].mean().to_frame().reset_index()
beauty_income = beauty_income.sort_values(by =['Income_Per_Year'])
X = beauty_income['Beauty_Level']
y = beauty_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### 2. Education

# %%
education_income = data.groupby(['Education'])['Income_Per_Year'].mean().to_frame().reset_index()
education_income = education_income.sort_values(by =['Income_Per_Year'])
X = education_income['Education']
y = education_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 28 artists>

# %% [markdown]
# ### 3. Social Media Followers

# %%
X = data['Social_Media_Followers']
y = data['Income_Per_Year']
plt.figure(figsize=(10,10))
plt.scatter(X, y, c='orange')

# %% [markdown]
# ### 4. Years Active

# %%
years_income = data.groupby(['Years_Active'])['Income_Per_Year'].mean().to_frame().reset_index()
years_income = years_income.sort_values(by =['Income_Per_Year'])
X = years_income['Years_Active']
y = years_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# ### 5. Age

# %%
age_income = data.groupby(['Age'])['Income_Per_Year'].mean().to_frame().reset_index()
age_income = age_income.sort_values(by =['Income_Per_Year'])
X = age_income['Age']
y = age_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# ### 6. MBTI

# %%
mbti_income = data.groupby(['MBTI_Personality'])['Income_Per_Year'].mean().to_frame().reset_index()
mbti_income = mbti_income.sort_values(by =['Income_Per_Year'])
X = mbti_income['MBTI_Personality']
y = mbti_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 16 artists>

# %% [markdown]
# ### 7. Genres

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Gender', 'Age', 'Nationality', 'Years_Active',
#        'Genre_Niche', 'Beauty_Level', 'Skills', 'Education', 'Award_Wins',
#        'Media_Mentions', 'Social_Media_Followers', 'Social_Media_Likes',
#        'Network_Size', 'MBTI_Personality', 'Income_Per_Year', 'First_Name',
#        'Last_Name', 'Genre_Niche_1', 'Genre_Niche_2', 'Skill_1', 'Skill_2',
#        'Skill_3'],
#       dtype='object')

# %%
g_income = data.groupby(['Genre_Niche_1'])['Income_Per_Year'].mean().to_frame().reset_index()
g_income = g_income.sort_values(by =['Income_Per_Year'])
X = g_income['Genre_Niche_1']
y = g_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 28 artists>

# %% [markdown]
# ### 8. Skills

# %%
s_income = data.groupby(['Skill_1'])['Income_Per_Year'].mean().to_frame().reset_index()
s_income = s_income.sort_values(by =['Income_Per_Year'])
X = s_income['Skill_1']
y = s_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 29 artists>

# %%
s_income = data.groupby(['Skill_2'])['Income_Per_Year'].mean().to_frame().reset_index()
s_income = s_income.sort_values(by =['Income_Per_Year'])
X = s_income['Skill_2']
y = s_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 32 artists>

# %%
s_income = data.groupby(['Skill_3'])['Income_Per_Year'].mean().to_frame().reset_index()
s_income = s_income.sort_values(by =['Income_Per_Year'])
X = s_income['Skill_3']
y = s_income['Income_Per_Year']
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(X, y)
# Out:
# <BarContainer object of 42 artists>
